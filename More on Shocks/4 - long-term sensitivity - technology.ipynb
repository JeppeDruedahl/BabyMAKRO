# %% [markdown]
# # Technology shock - Long-term analysis

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - 1. [Setup](#toc1_)
# - 2. [IRFs and figures](#toc2_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=false
# 	minLevel=2
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
# %load_ext autoreload
# %autoreload 2

import time
import pickle
import numpy as np
from scipy import optimize

import matplotlib.pyplot as plt   
plt.rcParams.update({"axes.grid":True,"grid.color":"black","grid.alpha":"0.25","grid.linestyle":"--"})
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

from BabyMAKROModel import BabyMAKROModelClass

# %% [markdown]
# ## 1. <a id='toc1_'></a>[Setup](#toc0_)

# %%
model = BabyMAKROModelClass(name='baseline')

# %% [markdown]
# **Unpack namespaces:**

# %%
par = model.par                 
ss = model.ss                   
sol = model.sol

# %% [markdown]
# **Inputs for figures:**

# %%
Tshock = 50                                                 # length of shock
persistence = np.array([0.80**np.arange(Tshock)])           # persistence of shock       
persistence = persistence.reshape((Tshock,1)) 
shock = ['Gamma']                                           # technology shock
shock_size = [0.01]                                         # shock size
varlist = ['Gamma','Y','K','C','A','B']                     # variable list for figures

# %% [markdown]
# ## 2. <a id='toc2_'></a>[IRFs and figures](#toc0_)

# %%
model.plot_long_term_IRFs(Tshock,persistence,shock,shock_size,'mu_Aq',par.mu_Aq/2,varlist)
model.plot_long_term_IRFs(Tshock,persistence,shock,shock_size,'gamma',par.gamma*2,varlist)
model.plot_long_term_IRFs(Tshock,persistence,shock,shock_size,'W_U',par.W_U*1.1,varlist)
model.plot_long_term_IRFs(Tshock,persistence,shock,shock_size,'beta',par.beta+0.02,varlist)
model.plot_long_term_IRFs(Tshock,persistence,shock,shock_size,'r_hh',par.r_hh+0.02,varlist)
model.plot_long_term_IRFs(Tshock,persistence,shock,shock_size,'Lambda',par.Lambda/2,varlist)
model.plot_long_term_IRFs(Tshock,persistence,shock,shock_size,'m_s_ss',par.m_s_ss/2,varlist)
model.plot_long_term_IRFs(Tshock,persistence,shock,shock_size,'m_v_ss',par.m_v_ss/2,varlist)
model.plot_long_term_IRFs(Tshock,persistence,shock,shock_size,'delta_L_a_fac',par.delta_L_a_fac*2,varlist)
model.plot_long_term_IRFs(Tshock,persistence,shock,shock_size,'epsilon_B',par.epsilon_B*2,varlist)
model.plot_long_term_IRFs(Tshock,persistence,shock,shock_size,'delta_K',par.delta_K*1.5,varlist)
# Out:
# model compiled, 1.0 mins 24 secs
# model compiled, 0.1 secs
# model compiled, 0.1 secs
# model compiled, 0.1 secs
# model compiled, 0.1 secs
# model compiled, 0.1 secs
# model compiled, 0.1 secs
# model compiled, 0.1 secs
# model compiled, 0.1 secs
# model compiled, 0.1 secs
# model compiled, 0.1 secs
# model compiled, 0.1 secs
# model compiled, 0.1 secs
# model compiled, 0.1 secs
# model compiled, 0.1 secs
# model compiled, 0.1 secs
# model compiled, 0.1 secs
# model compiled, 0.1 secs
# model compiled, 0.1 secs
# model compiled, 0.1 secs
# model compiled, 0.1 secs
# model compiled, 0.1 secs
