# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt   
plt.style.use('seaborn-whitegrid')
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

from BabyMAKROModel import BabyMAKROModelClass
# Out:
# C:\Users\nbk863\AppData\Local\Temp\ipykernel_15208\2007051729.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# # Setup

# %%
model = BabyMAKROModelClass(name='baseline')

# %%
par = model.par
ss = model.ss
sol = model.sol

# %% [markdown]
# # Find IRF

# %%
shock1 = ['chi']
shock2 = ['P_F','P_M_C','P_M_G','P_M_I','P_M_X']
Tshock = 50
persistence = 0.80**np.arange(Tshock)
shock_1_size = 0.01
Modellist = model.multi_shock_model(Tshock,persistence,shock_1_size,shock1,0.5*shock_1_size,shock2)
# Out:
# Jacobian calculated in 1.0 mins 10 secs
# initial:
# t1-t0 = 0.01197 secs
# it = 3
#     max. abs. error = 4.35e-11
#     2.04e-12 in A_R_ini_error
#     9.77e-15 in Aq_diff
#     5.66e-14 in bargaining_cond
#     5.42e-14 in FOC_capital_agency
#     1.52e-11 in FOC_K_ell
#     4.35e-11 in mkt_clearing
#     8.84e-13 in PC
#
# solve: t1-t0 = 0.15720 secs
# evaluate + update: t3-t2 = 0.09351 secs
# Jacobian calculated in 30.6 secs
# initial:
# t1-t0 = 0.01097 secs
# it = 3
#     max. abs. error = 2.70e-12
#     3.35e-14 in A_R_ini_error
#     2.22e-15 in Aq_diff
#     4.66e-15 in bargaining_cond
#     2.22e-15 in FOC_capital_agency
#     2.58e-13 in FOC_K_ell
#     2.70e-12 in mkt_clearing
#     3.27e-14 in PC
#
# solve: t1-t0 = 0.16554 secs
# evaluate + update: t3-t2 = 0.08078 secs
# Jacobian calculated in 30.9 secs
# initial:
# t1-t0 = 0.01197 secs
# it = 3
#     max. abs. error = 2.88e-12
#     3.32e-14 in A_R_ini_error
#     1.33e-15 in Aq_diff
#     4.88e-15 in bargaining_cond
#     8.88e-15 in FOC_capital_agency
#     1.53e-12 in FOC_K_ell
#     2.88e-12 in mkt_clearing
#     8.21e-14 in PC
#
# solve: t1-t0 = 0.26846 secs
# evaluate + update: t3-t2 = 0.08477 secs

# %% [markdown]
# ## Figures

# %% [markdown]
# ### Long-view

# %%
model.multi_shock_IRF(Modellist,['All',r'$\chi$',r'$P^F$, $P^{M,*}$'],varlist=['chi','P_M_C','K','A','B'],ncol=3,T_IRF=par.T)

# %% [markdown]
# ### National accouting - quantities

# %%
model.multi_shock_IRF(Modellist,['All',r'$\chi$',r'$P^F$, $P^{M,*}$'],varlist=['Y','C','G','I','X','M'])

# %% [markdown]
# ### National accouting - prices

# %%
model.multi_shock_IRF(Modellist,['All',r'$\chi$',r'$P^F$, $P^{M,*}$'],varlist=['P_Y','P_C','P_G','P_I','P_X'])

# %% [markdown]
# ### Import Prices

# %%
model.multi_shock_IRF(Modellist,['All',r'$\chi$',r'$P^F$, $P^{M,*}$'],varlist=['P_M_C','P_M_G','P_M_I','P_M_X','P_F'])

# %% [markdown]
# ### Labor market

# %%
model.multi_shock_IRF(Modellist,['All',r'$\chi$',r'$P^F$, $P^{M,*}$'],varlist=['S','L_ubar','v','curlyM','m_v','m_s','delta_L','W','real_W'],abs=['m_v','m_s'])

# %% [markdown]
# ### Capital accumulation

# %%
model.multi_shock_IRF(Modellist,['All',r'$\chi$',r'$P^F$, $P^{M,*}$'],varlist=['K','I','r_K','P_I'],ncol=2)

# %% [markdown]
# ### Production firms

# %%
model.multi_shock_IRF(Modellist,['All',r'$\chi$',r'$P^F$, $P^{M,*}$'],varlist=['K','ell','Gamma','Y','r_K','r_ell'],ncol=2)

# %% [markdown]
# ### Phillips curve

# %%
model.multi_shock_IRF(Modellist,['All',r'$\chi$',r'$P^F$, $P^{M,*}$'],varlist=['Y','P_Y_0','P_Y'],ncol=2)

# %% [markdown]
# ### Government

# %%
model.multi_shock_IRF(Modellist,['All',r'$\chi$',r'$P^F$, $P^{M,*}$'],varlist=['G','B','tau'],abs=['tau'],Y_share=['B'])

# %% [markdown]
# ### Households - aggregate

# %%
model.multi_shock_IRF(Modellist,['All',r'$\chi$',r'$P^F$, $P^{M,*}$'],varlist=['L','U','inc','W','real_W','real_r_hh','C','A','Aq'],ncol=3,abs=['real_r_hh'])

# %%
model.multi_shock_IRF(Modellist,['All',r'$\chi$',r'$P^F$, $P^{M,*}$'],varlist=['C_HtM','C_R'],ncol=2)

# %% [markdown]
# ### Households - life-cycle

# %%
model.plot_IRF_hh(varlist=['L_a','L_ubar_a','S_a','inc_a','C_a','A_a'],t0_list=[-20,-10,0,10,20])
