# %% [markdown]
# Hands-to-mouth households

# %%
# %load_ext autoreload
# %autoreload 2

import time
import pickle
import numpy as np
from scipy import optimize

import matplotlib.pyplot as plt   
plt.style.use('seaborn-whitegrid')
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

from BabyMAKROModel import BabyMAKROModelClass

# %%
model = BabyMAKROModelClass(name='baseline') # create an instance of the model
par = model.par
ss = model.ss
sol = model.sol
model1 = model.copy()
model2 = model.copy()

# %%
Models = [model, model1, model2] #Create list of the models
Lambdas = [0, 0.2, 0.8] #Create list of Lambda values

for i in range(len(Models)):
    Models[i].par.Lambda = Lambdas[i]
    Models[i].find_ss()
    Models[i].calc_jac()
    Tshock = 50
    shock = 0.01*Models[i].ss.chi
    persistence = 0.8**np.arange(Tshock)
    Models[i].sol.chi[:Tshock] = Models[i].ss.chi + shock*persistence
    Models[i].find_IRF()
# Out:
# initial:
#    max. abs. error = 7.47e-01
#     0.00e+00 in bargaining_cond
#     2.87e-12 in Bq_match
#     0.00e+00 in FOC_capital_agency
#     8.88e-15 in FOC_K_ell
#     7.47e-01 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 7.47e-01
#     1.39e-05 in bargaining_cond
#     1.83e-03 in Bq_match
#     8.11e-06 in FOC_capital_agency
#     2.51e-04 in FOC_K_ell
#     6.60e-03 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.60e-03
#     5.43e-07 in bargaining_cond
#     4.41e-05 in Bq_match
#     3.59e-07 in FOC_capital_agency
#     9.70e-06 in FOC_K_ell
#     2.01e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.01e-04
#     1.59e-08 in bargaining_cond
#     1.37e-06 in Bq_match
#     1.09e-08 in FOC_capital_agency
#     2.81e-07 in FOC_K_ell
#     5.74e-06 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.74e-06
#     3.16e-11 in bargaining_cond
#     9.98e-09 in Bq_match
#     2.00e-11 in FOC_capital_agency
#     5.92e-10 in FOC_K_ell
#     1.17e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.17e-08
#     2.14e-12 in bargaining_cond
#     1.53e-10 in Bq_match
#     1.47e-12 in FOC_capital_agency
#     3.80e-11 in FOC_K_ell
#     7.56e-10 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 7.56e-10
#     2.93e-14 in bargaining_cond
#     2.02e-11 in Bq_match
#     3.82e-14 in FOC_capital_agency
#     2.93e-13 in FOC_K_ell
#     1.20e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.02e-11
#     2.93e-14 in bargaining_cond
#     1.70e-11 in Bq_match
#     3.26e-14 in FOC_capital_agency
#     1.01e-13 in FOC_K_ell
#     1.11e-11 in mkt_clearing
# initial:
#    max. abs. error = 1.13e+00
#     0.00e+00 in bargaining_cond
#     1.12e-12 in Bq_match
#     0.00e+00 in FOC_capital_agency
#     8.88e-15 in FOC_K_ell
#     1.13e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.13e+00
#     2.33e-05 in bargaining_cond
#     2.86e-03 in Bq_match
#     1.43e-05 in FOC_capital_agency
#     4.33e-04 in FOC_K_ell
#     1.29e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.29e-02
#     1.12e-06 in bargaining_cond
#     5.69e-05 in Bq_match
#     7.93e-07 in FOC_capital_agency
#     2.03e-05 in FOC_K_ell
#     4.87e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.87e-04
#     5.19e-08 in bargaining_cond
#     3.01e-06 in Bq_match
#     3.75e-08 in FOC_capital_agency
#     9.28e-07 in FOC_K_ell
#     2.20e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.20e-05
#     5.16e-10 in bargaining_cond
#     4.01e-08 in Bq_match
#     3.68e-10 in FOC_capital_agency
#     9.06e-09 in FOC_K_ell
#     2.18e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.18e-07
#     1.07e-11 in bargaining_cond
#     7.27e-10 in Bq_match
#     7.93e-12 in FOC_capital_agency
#     1.92e-10 in FOC_K_ell
#     4.43e-09 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 4.43e-09
#     5.95e-14 in bargaining_cond
#     1.30e-11 in Bq_match
#     5.51e-14 in FOC_capital_agency
#     1.21e-12 in FOC_K_ell
#     2.65e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 2.65e-11
#     3.24e-14 in bargaining_cond
#     1.38e-11 in Bq_match
#     3.49e-14 in FOC_capital_agency
#     1.14e-13 in FOC_K_ell
#     1.28e-11 in mkt_clearing
# initial:
#    max. abs. error = 1.21e+00
#     0.00e+00 in bargaining_cond
#     4.86e-13 in Bq_match
#     0.00e+00 in FOC_capital_agency
#     8.88e-15 in FOC_K_ell
#     1.21e+00 in mkt_clearing
#
# it = 0
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.21e+00
#     3.60e-05 in bargaining_cond
#     1.15e-03 in Bq_match
#     2.16e-05 in FOC_capital_agency
#     6.74e-04 in FOC_K_ell
#     1.80e-02 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 1
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.80e-02
#     2.16e-06 in bargaining_cond
#     2.93e-05 in Bq_match
#     1.50e-06 in FOC_capital_agency
#     3.90e-05 in FOC_K_ell
#     8.69e-04 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 2
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 8.69e-04
#     1.31e-07 in bargaining_cond
#     1.91e-06 in Bq_match
#     9.34e-08 in FOC_capital_agency
#     2.33e-06 in FOC_K_ell
#     5.15e-05 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 3
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 5.15e-05
#     2.49e-09 in bargaining_cond
#     3.95e-08 in Bq_match
#     1.81e-09 in FOC_capital_agency
#     4.42e-08 in FOC_K_ell
#     9.85e-07 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 4
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 9.85e-07
#     3.76e-11 in bargaining_cond
#     6.83e-10 in Bq_match
#     2.67e-11 in FOC_capital_agency
#     6.67e-10 in FOC_K_ell
#     1.45e-08 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 5
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 1.45e-08
#     1.59e-13 in bargaining_cond
#     7.96e-12 in Bq_match
#     1.12e-13 in FOC_capital_agency
#     2.79e-12 in FOC_K_ell
#     6.02e-11 in mkt_clearing
#  evaluate: t1-t0 = 0.0 secs
#  update_jac: t1-t0 = 0.0 secs
#
# it = 6
#  solve: t1-t0 = 0.1 secs
#    max. abs. error = 6.02e-11
#     3.11e-14 in bargaining_cond
#     3.24e-12 in Bq_match
#     2.84e-14 in FOC_capital_agency
#     1.10e-13 in FOC_K_ell
#     1.26e-11 in mkt_clearing

# %%
fig = plt.figure(figsize=(2*6,2*6/1.5))

ax = fig.add_subplot(2,2,1)
ax.plot(Models[0].ss.B_a)
ax.plot(Models[1].ss.B_a)
ax.plot(Models[2].ss.B_a)
ax.set_ylabel('')
ax.set_title('$B_a$')

ax = fig.add_subplot(2,2,2)
ax.plot(Models[0].ss.C_a)
ax.plot(Models[1].ss.C_a)
ax.plot(Models[2].ss.C_a)
ax.set_ylabel('')
ax.set_title('$C_a$')

ax = fig.add_subplot(2,2,3)
ax.plot(Models[0].ss.C_R)
ax.plot(Models[1].ss.C_R)
ax.plot(Models[2].ss.C_R)
ax.set_ylabel('')
ax.set_title('$C^R_a$')

ax = fig.add_subplot(2,2,4)
ax.plot(Models[0].ss.C_HTM,label=f'$\lambda$ = {Models[0].par.Lambda}')
ax.plot(Models[1].ss.C_HTM,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot(Models[2].ss.C_HTM,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.set_ylabel('')
ax.set_title('$C^{HtM}_a$')
ax.legend(frameon=True);

# %%
T_IRF = 500

fig = plt.figure(figsize=(3*6,3*6/1.5))

ax = fig.add_subplot(3,3,1)
ax.plot((Models[0].sol.chi[:T_IRF]/Models[0].ss.chi-1)*100,label=f'$\lambda$ = {Models[0].par.Lambda}')
ax.plot((Models[1].sol.chi[:T_IRF]/Models[1].ss.chi-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.chi[:T_IRF]/Models[2].ss.chi-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Export demand, $\chi_t$')

ax = fig.add_subplot(3,3,2)
ax.plot((Models[0].sol.X[:T_IRF]/Models[0].ss.X-1)*100,label=f'$\lambda$ = {Models[0].par.Lambda}')
ax.plot((Models[1].sol.X[:T_IRF]/Models[1].ss.X-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.X[:T_IRF]/Models[2].ss.X-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Export, $X_t$')

ax = fig.add_subplot(3,3,3)
ax.plot((Models[0].sol.Y[:T_IRF]/Models[0].ss.Y-1)*100,label=f'$\lambda$ = {Models[0].par.Lambda}')
ax.plot((Models[1].sol.Y[:T_IRF]/Models[1].ss.Y-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.Y[:T_IRF]/Models[2].ss.Y-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Production, $Y_t$')
ax.legend(frameon=True)

ax = fig.add_subplot(3,3,4)
ax.plot((Models[0].sol.K[:T_IRF]/Models[0].ss.K-1)*100,label=f'$\lambda$ = {Models[0].par.Lambda}')
ax.plot((Models[1].sol.K[:T_IRF]/Models[1].ss.K-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.K[:T_IRF]/Models[2].ss.K-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Capital, $K_t$')

ax = fig.add_subplot(3,3,5)
ax.plot((Models[0].sol.L[:T_IRF]/Models[0].ss.L-1)*100,label=f'$\lambda$ = {Models[0].par.Lambda}')
ax.plot((Models[1].sol.L[:T_IRF]/Models[1].ss.L-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.L[:T_IRF]/Models[2].ss.L-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Employment, $L_t$')

ax = fig.add_subplot(3,3,6)
ax.plot((Models[0].sol.w[:T_IRF]/Models[0].ss.w-1)*100,label=f'$\lambda$ = {Models[0].par.Lambda}')
ax.plot((Models[1].sol.w[:T_IRF]/Models[1].ss.w-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.w[:T_IRF]/Models[2].ss.w-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Wage, $w_t$')

ax = fig.add_subplot(3,3,7)
ax.plot((Models[0].sol.C[:T_IRF]/Models[0].ss.C-1)*100,label=f'$\lambda$ = {Models[0].par.Lambda}')
ax.plot((Models[1].sol.C[:T_IRF]/Models[1].ss.C-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.C[:T_IRF]/Models[2].ss.C-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Consumption, $C_t$')

ax = fig.add_subplot(3,3,8)
ax.plot((Models[0].sol.B[:T_IRF]/Models[0].ss.B-1)*100,label=f'$\lambda$ = {Models[0].par.Lambda}')
ax.plot((Models[1].sol.B[:T_IRF]/Models[1].ss.B-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.B[:T_IRF]/Models[2].ss.B-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Savings, $B_t$')

ax = fig.add_subplot(3,3,9)
ax.plot((Models[0].sol.Bq[:T_IRF]/Models[0].ss.Bq-1)*100,label=f'$\lambda$ = {Models[0].par.Lambda}')
ax.plot((Models[1].sol.Bq[:T_IRF]/Models[1].ss.Bq-1)*100,label=f'$\lambda$ = {Models[1].par.Lambda}')
ax.plot((Models[2].sol.Bq[:T_IRF]/Models[2].ss.Bq-1)*100,label=f'$\lambda$ = {Models[2].par.Lambda}')
ax.set_ylabel('% of s.s.')
ax.set_title('Bequest, $B^q_t$');
