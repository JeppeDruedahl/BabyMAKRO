# %% [markdown]
# # Technology shock - Long-term analysis

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - 1. [Setup](#toc1_)
# - 2. [IRFs and figures](#toc2_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=false
# 	minLevel=2
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
# %load_ext autoreload
# %autoreload 2

import time
import pickle
import numpy as np
from scipy import optimize

import matplotlib.pyplot as plt   
plt.rcParams.update({"axes.grid":True,"grid.color":"black","grid.alpha":"0.25","grid.linestyle":"--"})
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

from BabyMAKROModel import BabyMAKROModelClass

# %% [markdown]
# ## 1. <a id='toc1_'></a>[Setup](#toc0_)

# %%
model = BabyMAKROModelClass(name='baseline')                # create an instance of the model

# %% [markdown]
# **Unpacking namespaces:**

# %%
par = model.par                 
ss = model.ss                   
sol = model.sol

# %% [markdown]
# **Inputs for figures:**

# %%
Tshock = 50                                                 # length of shock
persistence = 0.80**np.arange(Tshock)                       # persistence of shock
shocks = ['chi','P_F','P_M_C','P_M_G','P_M_I','P_M_X']      # export shock
shock_sizes = [0.01,0.005,0.005,0.005,0.005,0.005]                # shock sizes                               
varlist = ['chi','Y','K','C','A','B']                       # variable list for figures

# %% [markdown]
# ## 2. <a id='toc2_'></a>[IRFs and figures](#toc0_)

# %%
model.plot_long_term_IRFs(Tshock,persistence,shocks,shock_sizes,'mu_Aq',par.mu_Aq/2,varlist)
model.plot_long_term_IRFs(Tshock,persistence,shocks,shock_sizes,'eta',0.5,varlist)
model.plot_long_term_IRFs(Tshock,persistence,shocks,shock_sizes,'W_U',par.W_U*1.1,varlist)
model.plot_long_term_IRFs(Tshock,persistence,shocks,shock_sizes,'beta',par.beta+0.02,varlist)
model.plot_long_term_IRFs(Tshock,persistence,shocks,shock_sizes,'r_hh',par.r_hh-0.02,varlist)
model.plot_long_term_IRFs(Tshock,persistence,shocks,shock_sizes,'Lambda',par.Lambda/2,varlist)
model.plot_long_term_IRFs(Tshock,persistence,shocks,shock_sizes,'m_s_ss',par.m_s_ss/2,varlist)
model.plot_long_term_IRFs(Tshock,persistence,shocks,shock_sizes,'m_v_ss',par.m_v_ss/2,varlist)
model.plot_long_term_IRFs(Tshock,persistence,shocks,shock_sizes,'epsilon_B',par.epsilon_B*2,varlist)
model.plot_long_term_IRFs(Tshock,persistence,shocks,shock_sizes,'delta_K',par.delta_K*1.5,varlist)
